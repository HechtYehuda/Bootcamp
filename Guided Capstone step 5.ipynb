# %% [markdown]
# # Guided Capstone Step 4. Pre-Processing and Training Data Development

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
#
# 2.   Data Wrangling
#
#
# 3.   Exploratory Data Analysis
#
# 4.   **Pre-processing and Training Data Development**
#  * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 3 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# **<font color='teal'>  Load the csv file you created in step 3, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
os.getcwd()
# Out:
# '/Users/yehudahecht/Google Drive/Springboard/Bootcamp/6 - Applying the Data Science Method/6.5 - Modeling'

# %%
path = '../data/'
file = 'step3_output.csv'
df = pd.read_csv(path+file, index_col=0)
df.head()
# Out:
#                   Name    state  summit_elev  vertical_drop  base_elev  trams  \
# 0       Alyeska Resort   Alaska         3939           2500        250      1
# 1  Eaglecrest Ski Area   Alaska         2600           1540       1200      0
# 2     Hilltop Ski Area   Alaska         2090            294       1796      0
# 3     Arizona Snowbowl  Arizona        11500           2300       9200      0
# 4  Sunrise Park Resort  Arizona        11100           1800       9200      0
#
#    fastEight  fastSixes  fastQuads  quad  ...  LongestRun_mi  \
# 0        0.0          0          2     2  ...            1.0
# 1        0.0          0          0     0  ...            2.0
# 2        0.0          0          0     0  ...            1.0
# 3        0.0          1          0     2  ...            2.0
# 4        0.0          0          1     2  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             0.0
# 2            30.0
# 3             0.0
# 4            80.0
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               330 non-null    object
#  1   state              330 non-null    object
#  2   summit_elev        330 non-null    int64
#  3   vertical_drop      330 non-null    int64
#  4   base_elev          330 non-null    int64
#  5   trams              330 non-null    int64
#  6   fastEight          330 non-null    float64
#  7   fastSixes          330 non-null    int64
#  8   fastQuads          330 non-null    int64
#  9   quad               330 non-null    int64
#  10  triple             330 non-null    int64
#  11  double             330 non-null    int64
#  12  surface            330 non-null    int64
#  13  total_chairs       330 non-null    int64
#  14  Runs               330 non-null    float64
#  15  TerrainParks       330 non-null    float64
#  16  LongestRun_mi      330 non-null    float64
#  17  SkiableTerrain_ac  330 non-null    float64
#  18  Snow Making_ac     330 non-null    float64
#  19  daysOpenLastYear   330 non-null    float64
#  20  yearsOpen          330 non-null    float64
#  21  averageSnowfall    330 non-null    float64
#  22  AdultWeekday       330 non-null    float64
#  23  AdultWeekend       330 non-null    float64
#  24  projectedDaysOpen  330 non-null    float64
#  25  NightSkiing_ac     330 non-null    float64
# dtypes: float64(13), int64(11), object(2)
# memory usage: 69.6+ KB

# %% [markdown]
# ## Create dummy features for categorical variables

# %% [markdown]
# **<font color='teal'> Create dummy variables for `state`. Add the dummies back to the dataframe and remove the original column for `state`. </font>**
#
# Hint: you can see an example of how to execute this in Aiden's article on preprocessing [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-pre-processing-and-training-data-development-fd2d75182967).

# %%
# for categorical in ['state','clusters']:
#     states = pd.get_dummies(df[categorical])
#     df[states.columns] = states
#     df.drop(categorical, axis=1, inplace=True)
# df.info()    




states = pd.get_dummies(df['state'])
df[states.columns] = states
df.drop('state', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 329
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               330 non-null    object
#  1   summit_elev        330 non-null    int64
#  2   vertical_drop      330 non-null    int64
#  3   base_elev          330 non-null    int64
#  4   trams              330 non-null    int64
#  5   fastEight          330 non-null    float64
#  6   fastSixes          330 non-null    int64
#  7   fastQuads          330 non-null    int64
#  8   quad               330 non-null    int64
#  9   triple             330 non-null    int64
#  10  double             330 non-null    int64
#  11  surface            330 non-null    int64
#  12  total_chairs       330 non-null    int64
#  13  Runs               330 non-null    float64
#  14  TerrainParks       330 non-null    float64
#  15  LongestRun_mi      330 non-null    float64
#  16  SkiableTerrain_ac  330 non-null    float64
#  17  Snow Making_ac     330 non-null    float64
#  18  daysOpenLastYear   330 non-null    float64
#  19  yearsOpen          330 non-null    float64
#  20  averageSnowfall    330 non-null    float64
#  21  AdultWeekday       330 non-null    float64
#  22  AdultWeekend       330 non-null    float64
#  23  projectedDaysOpen  330 non-null    float64
#  24  NightSkiing_ac     330 non-null    float64
#  25  Alaska             330 non-null    uint8
#  26  Arizona            330 non-null    uint8
#  27  California         330 non-null    uint8
#  28  Colorado           330 non-null    uint8
#  29  Connecticut        330 non-null    uint8
#  30  Idaho              330 non-null    uint8
#  31  Illinois           330 non-null    uint8
#  32  Indiana            330 non-null    uint8
#  33  Iowa               330 non-null    uint8
#  34  Maine              330 non-null    uint8
#  35  Maryland           330 non-null    uint8
#  36  Massachusetts      330 non-null    uint8
#  37  Michigan           330 non-null    uint8
#  38  Minnesota          330 non-null    uint8
#  39  Missouri           330 non-null    uint8
#  40  Montana            330 non-null    uint8
#  41  Nevada             330 non-null    uint8
#  42  New Hampshire      330 non-null    uint8
#  43  New Jersey         330 non-null    uint8
#  44  New Mexico         330 non-null    uint8
#  45  New York           330 non-null    uint8
#  46  North Carolina     330 non-null    uint8
#  47  Ohio               330 non-null    uint8
#  48  Oregon             330 non-null    uint8
#  49  Pennsylvania       330 non-null    uint8
#  50  Rhode Island       330 non-null    uint8
#  51  South Dakota       330 non-null    uint8
#  52  Tennessee          330 non-null    uint8
#  53  Utah               330 non-null    uint8
#  54  Vermont            330 non-null    uint8
#  55  Virginia           330 non-null    uint8
#  56  Washington         330 non-null    uint8
#  57  West Virginia      330 non-null    uint8
#  58  Wisconsin          330 non-null    uint8
#  59  Wyoming            330 non-null    uint8
# dtypes: float64(13), int64(11), object(1), uint8(35)
# memory usage: 78.3+ KB

# %%
pd.set_option('display.max_rows', None)
df.agg([min, max]).T
# Out:
#                                 min                            max
# Name               49 Degrees North  Yosemite Ski & Snowboard Area
# summit_elev                     315                          13487
# vertical_drop                    60                           4425
# base_elev                        70                          10800
# trams                             0                              4
# fastEight                         0                              1
# fastSixes                         0                              6
# fastQuads                         0                             15
# quad                              0                              8
# triple                            0                              8
# double                            0                             14
# surface                           0                             15
# total_chairs                      0                             41
# Runs                              3                            341
# TerrainParks                      0                             14
# LongestRun_mi                     0                              6
# SkiableTerrain_ac                 8                          26819
# Snow Making_ac                    2                           3379
# daysOpenLastYear                  3                            305
# yearsOpen                         6                           2019
# averageSnowfall                  18                            669
# AdultWeekday                     15                            179
# AdultWeekend                     17                            179
# projectedDaysOpen                30                            305
# NightSkiing_ac                    0                            650
# Alaska                            0                              1
# Arizona                           0                              1
# California                        0                              1
# Colorado                          0                              1
# Connecticut                       0                              1
# Idaho                             0                              1
# Illinois                          0                              1
# Indiana                           0                              1
# Iowa                              0                              1
# Maine                             0                              1
# Maryland                          0                              1
# Massachusetts                     0                              1
# Michigan                          0                              1
# Minnesota                         0                              1
# Missouri                          0                              1
# Montana                           0                              1
# Nevada                            0                              1
# New Hampshire                     0                              1
# New Jersey                        0                              1
# New Mexico                        0                              1
# New York                          0                              1
# North Carolina                    0                              1
# Ohio                              0                              1
# Oregon                            0                              1
# Pennsylvania                      0                              1
# Rhode Island                      0                              1
# South Dakota                      0                              1
# Tennessee                         0                              1
# Utah                              0                              1
# Vermont                           0                              1
# Virginia                          0                              1
# Washington                        0                              1
# West Virginia                     0                              1
# Wisconsin                         0                              1
# Wyoming                           0                              1

# %% [markdown]
# ## Standardize the magnitude of numeric features

# %% [markdown]
# **<font color='teal'> Using sklearn preprocessing standardize the scale of the features of the dataframe except the name of the resort which we done't need in the dataframe for modeling, so it can be droppped here as well. Also, we want to hold out our response variable(s) so we can have their true values available for model performance review. Let's set `AdultWeekend` to the y variable as our response for scaling and modeling. Later we will go back and consider the `AdultWeekday`, `dayOpenLastYear`, and `projectedDaysOpen`. For now leave them in the development dataframe. </font>**

# %%
# first we import the preprocessing package from the sklearn library
from sklearn import preprocessing

# Declare an explanatory variable, called X,and assign it the result of dropping 'Name' and 'AdultWeekend' from the df
X = df.drop(['Name','AdultWeekend'], axis=1)

# Declare a response variable, called y, and assign it the AdultWeekend column of the df 
y = df.AdultWeekend

# Here we use the StandardScaler() method of the preprocessing package, and then call the fit() method with parameter X 
scaler = preprocessing.StandardScaler().fit(X)

# Declare a variable called X_scaled, and assign it the result of calling the transform() method with parameter X 
X_scaled=scaler.transform(X)
# Out:
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Split into training and testing datasets

# %% [markdown]
# **<font color='teal'> Using sklearn model selection import train_test_split, and create a 75/25 split with the y = `AdultWeekend`. We will start by using the adult weekend ticket price as our response variable for modeling.</font>**

# %%
# Import the train_test_split function from the sklearn.model_selection utility.  
from sklearn.model_selection import train_test_split

# Get the 1-dimensional flattened array of our response variable y by calling the ravel() function on y
y = y.ravel()
print(y)

# Call the train_test_split() function with the first two parameters set to X_scaled and y 
# Declare four variables, X_train, X_test, y_train and y_test separated by commas 
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)
# Out:
# [ 85.          53.          34.          89.          78.
#   47.          64.16681004  64.16681004  64.16681004  78.
#   75.          64.16681004  64.16681004  64.16681004 159.
#   59.          84.          69.          64.16681004  64.16681004
#   83.          64.16681004  79.          50.         125.
#   69.          85.         179.          64.16681004  64.16681004
#  158.          64.16681004  89.          64.16681004  25.
#   64.16681004  79.          89.          71.          79.
#   56.          84.          64.16681004  65.         139.
#   64.16681004  64.16681004  72.          65.          60.
#   55.          62.          42.          64.          70.
#   42.          47.          32.          47.          64.16681004
#   81.          62.          43.          64.16681004  71.
#   55.          64.16681004  35.          40.          45.
#   52.          39.          40.          46.          30.
#   43.          55.          49.          64.16681004  32.
#   75.          99.         105.          79.          68.
#   45.          45.          49.          55.          81.
#   58.          40.          60.          64.16681004  71.
#   47.          35.          69.          48.          65.
#   98.          64.16681004  49.          37.          64.
#   49.          64.16681004  49.          68.          59.
#   34.          45.          20.          45.          85.
#   57.          45.          78.          49.          35.
#   42.          50.          45.          64.16681004  60.
#   45.          47.          44.          37.          17.
#   58.          35.34        84.          46.          48.
#   59.          60.          55.          49.          47.
#   64.16681004  42.          63.          49.          48.
#   46.          39.          50.          67.          47.
#   39.          81.          99.          20.          70.
#  135.          89.          59.          99.          79.
#   64.16681004  69.          50.          92.          58.
#   64.16681004  93.          72.          84.          93.
#   45.          89.          64.16681004  79.99        77.
#   20.          49.          79.          55.          47.
#   74.          80.         110.          72.          32.
#   76.          50.          69.          35.          88.
#   63.2         42.          78.          75.          58.
#   89.          60.          59.          38.          30.
#   54.          40.          63.          67.          45.
#   48.          59.          59.          57.          49.
#   55.          59.          96.          46.          95.
#   39.          64.          70.          43.          68.
#   75.          65.          43.          44.          44.
#   44.          52.          40.          39.          59.
#   52.          99.          64.16681004  70.          64.16681004
#   64.16681004  60.          60.          62.          65.
#   68.          65.          70.          64.16681004  69.
#   65.          77.          33.          73.          87.
#   65.          44.          64.16681004  64.16681004  45.
#   71.          64.16681004  45.          58.          65.
#  116.          50.          59.          85.         169.
#   60.          64.16681004  88.         115.         125.
#  119.          80.          50.          79.          91.
#   73.          89.         119.          64.16681004  74.
#   64.16681004  64.16681004  81.          79.          64.16681004
#   64.16681004 119.          75.          68.          64.16681004
#   64.16681004  64.16681004  62.          64.16681004  47.
#   99.          64.16681004  60.01        59.          64.16681004
#   95.          69.          68.          87.          92.
#   72.          65.          25.          64.          38.
#   64.16681004  65.          49.          92.          41.
#   56.          47.          44.          54.          48.
#   60.          66.          90.          48.          64.16681004
#   64.16681004  42.          59.          49.          49.        ]

# %% [markdown]
# Here we start the actual modeling work. First let's fit a multiple linear regression model to predict the `AdultWeekend` price.

# %% [markdown]
# # Guided Capstone Step 5. Modeling

# %% [markdown]
# This is the fifth step in the Data Science Method. In the previous steps you cleaned and prepared the datasets. Now it's time to get into the most exciting part: modeling! In this exercise, you'll build three different models and compare each model's performance. In the end, you'll choose the best model for demonstrating insights to Big Mountain management.
#
#
#
# ### **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.   **Modeling**
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# ## Fit Models with a Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn, fit the model on your training dataset.</font>**

# %% [markdown]
# #### Model 1

# %%
#all first model set
from sklearn import linear_model
from sklearn.metrics import explained_variance_score,mean_absolute_error
lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)

# %% [markdown]
# **<font color='teal'> Predict on the testing dataset and score the model performance with the y_test set and the y-pred values. The explained variance is a measure of the variation explained by the model. This is also known as the R-squared value. </font>**
#
# Hint: you will have to use the `predict()` method here as it's used in this [DSM article](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-modeling-56b4233cad1b) about modeling.

# %%
# Make a variable called y_pred and assign it the result of calling predict() on our model variable with parameter X_test
y_pred = model.predict(X_test)

# %% [markdown]
# ## Review Model Outcomes — Iterate over additional models as needed

# %%
# You might want to use the explained_variance_score() and mean_absolute_error() metrics.
# To do so, you will need to import them from sklearn.metrics. 
# You can plug y_test and y_pred into the functions to evaluate the model
explained_variance_score(y_test, y_pred)
# Out:
# 0.934943830806142

# %%
explained_variance_score?

# %%
y_train_pred = model.predict(X_train)
explained_variance_score(y_train, y_train_pred)
# Out:
# 0.9119338128199863

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 5.066784156515915

# %% [markdown]
# **<font color='teal'> Print the intercept value from the linear model. </font>**
#
# Hint: our linear regression model `lm` has an attribute `intercept_` for the intercept

# %%
lm.intercept_
# Out:
# 64.10401181767517

# %% [markdown]
# **<font color='teal'> The intercept is the mean `AdultWeekend` price for all the resorts given the other characteristics. The addition or subtraction of each of the coefficient values in the regression are numeric adjustments applied to the intercept to provide a particular observation's value for the resulting `AdultWeekend` value. Also, because we took the time to scale our x values in the training data, we can compare each of the coeeficients for the features to determine the feature importances. Print the coefficient values from the linear model and sort in descending order to identify the top ten most important features.</font>**
#
#
# Hint: make sure to review the absolute value of the coefficients, because the adjustment may be positive or negative, but what we are looking for is the magnitude of impact on our response variable.

# %%
# You might want to make a pandas DataFrame displaying the coefficients for each state like so: 
# pd.DataFrame(abs(lm.coef_), X.columns, columns=['Coefficient'])
pd.DataFrame(abs(lm.coef_), X.columns, columns=['Coefficient']).sort_values(by='Coefficient', ascending=False)
# Out:
#                     Coefficient
# total_chairs       1.391993e+12
# fastQuads          5.277077e+11
# surface            4.944226e+11
# double             4.357035e+11
# triple             3.886775e+11
# quad               3.150087e+11
# New York           1.698896e+11
# Michigan           1.603297e+11
# fastSixes          1.564392e+11
# Colorado           1.412597e+11
# California         1.382358e+11
# trams              1.344169e+11
# Pennsylvania       1.319133e+11
# Wisconsin          1.216344e+11
# New Hampshire      1.216344e+11
# Vermont            1.179594e+11
# Minnesota          1.141403e+11
# Utah               1.101623e+11
# Montana            1.060073e+11
# Idaho              1.060073e+11
# Massachusetts      1.016537e+11
# Oregon             9.707482e+10
# Washington         9.707482e+10
# New Mexico         9.223705e+10
# Maine              9.223705e+10
# Wyoming            8.709727e+10
# North Carolina     7.566234e+10
# Ohio               6.917645e+10
# Connecticut        6.917645e+10
# Nevada             6.196842e+10
# Illinois           6.196842e+10
# Virginia           6.196842e+10
# West Virginia      6.196842e+10
# Iowa               5.374847e+10
# Alaska             5.374847e+10
# South Dakota       4.395250e+10
# Arizona            4.395250e+10
# Indiana            4.395250e+10
# Missouri           4.395250e+10
# New Jersey         4.395250e+10
# Rhode Island       3.112645e+10
# Maryland           3.112645e+10
# Tennessee          3.112645e+10
# fastEight          1.321450e+10
# AdultWeekday       1.931817e+01
# summit_elev        1.793423e+01
# base_elev          1.737383e+01
# vertical_drop      5.712340e+00
# Runs               1.154793e+00
# NightSkiing_ac     8.005369e-01
# daysOpenLastYear   4.022797e-01
# LongestRun_mi      3.943369e-01
# yearsOpen          3.763055e-01
# averageSnowfall    3.086208e-01
# Snow Making_ac     2.237884e-01
# SkiableTerrain_ac  1.800893e-01
# projectedDaysOpen  1.621494e-01
# TerrainParks       1.287740e-01

# %% [markdown]
# **<font color='teal'>You should see that the top ten important features are different states. However, the state is not something the managers at the Big Mountain Resort can do anything about. Given that we care more about actionable traits associated with ticket pricing, rebuild the model without the state features and compare the results. </font>**
#
# Hint: Try to construct another model using exactly the steps we followed above.

# %% [markdown]
# #### Model 2

# %%
to_drop = list(states.columns)
[to_drop.append(i) for i in ['Name','AdultWeekend']]
no_states = df.drop(to_drop, axis=1)
scaler2 = preprocessing.StandardScaler().fit(no_states)
X_scaled = scaler2.transform(no_states)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

model2 = lm.fit(X_train, y_train)
y_pred = model2.predict(X_test)
explained_variance_score(y_test, y_pred)
# Out:
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """
# 0.924327557929588

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 5.501951502893553

# %%
pd.DataFrame(abs(lm.coef_), no_states.columns, columns=['Coefficient']).sort_values(by='Coefficient', ascending=False)
# Out:
#                    Coefficient
# AdultWeekday         20.236082
# summit_elev          12.589033
# base_elev             9.767936
# vertical_drop         4.353867
# averageSnowfall       1.931107
# quad                  1.556483
# triple                1.386797
# surface               1.258499
# daysOpenLastYear      1.174548
# Runs                  1.061541
# fastQuads             0.727970
# total_chairs          0.689709
# projectedDaysOpen     0.475856
# NightSkiing_ac        0.394906
# fastSixes             0.370696
# double                0.308783
# yearsOpen             0.286602
# SkiableTerrain_ac     0.269349
# LongestRun_mi         0.217660
# TerrainParks          0.189711
# trams                 0.169124
# fastEight             0.073687
# Snow Making_ac        0.027834

# %% [markdown]
# **<font color='teal'> When reviewing our new model coefficients, we see `summit_elev` is now in the number two spot. This is also difficult to change from a management prespective and highly correlated with `base_elev` and `vertical_drop`.  This time, rebuild the model without the state features and without the `summit_elev` and without `base_elev`and compare the results. </font>**

# %% [markdown]
# #### Model 3

# %%
[to_drop.append(i) for i in ['summit_elev','base_elev']]
no_states_elev = df.drop(to_drop, axis=1)
scaler3 = preprocessing.StandardScaler().fit(no_states_elev)
X_scaled = scaler3.transform(no_states_elev)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

model3 = lm.fit(X_train, y_train)
y_pred = model3.predict(X_test)
explained_variance_score(y_test, y_pred)
# Out:
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# 0.9257250741371149

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 5.463450934547313

# %%
pd.DataFrame(abs(lm.coef_), no_states_elev.columns, columns=['Coefficient']).sort_values(by='Coefficient', ascending=False)
# Out:
#                    Coefficient
# AdultWeekday         20.159761
# averageSnowfall       2.264604
# quad                  1.597019
# triple                1.354509
# Runs                  1.253202
# surface               1.244158
# vertical_drop         1.117666
# daysOpenLastYear      1.050756
# fastQuads             0.812179
# total_chairs          0.733674
# NightSkiing_ac        0.531579
# fastSixes             0.376235
# SkiableTerrain_ac     0.351879
# double                0.316856
# yearsOpen             0.306203
# projectedDaysOpen     0.251268
# LongestRun_mi         0.199760
# trams                 0.146300
# Snow Making_ac        0.145668
# TerrainParks          0.105424
# fastEight             0.077582

# %% [markdown]
# #### Model 4

# %%
to_drop = ['Name','AdultWeekend','summit_elev','base_elev']

no_elev = df.drop(to_drop, axis=1)
scaler4 = preprocessing.StandardScaler().fit(no_elev)
X_scaled = scaler4.transform(no_elev)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

model4 = lm.fit(X_train, y_train)
y_pred = model4.predict(X_test)
explained_variance_score(y_test, y_pred)
# Out:
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/yehudahecht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   """
# 0.9415452939934688

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 4.8970044254431215

# %%
pd.DataFrame(abs(lm.coef_), no_elev.columns, columns=['Coefficient']).sort_values(by='Coefficient', ascending=False)
# Out:
#                     Coefficient
# New York           1.029836e+13
# Michigan           9.718851e+12
# Colorado           8.562871e+12
# California         8.379567e+12
# Pennsylvania       7.996311e+12
# Wisconsin          7.373225e+12
# New Hampshire      7.373225e+12
# Vermont            7.150454e+12
# Minnesota          6.918951e+12
# Utah               6.677809e+12
# Montana            6.425943e+12
# Idaho              6.425943e+12
# Massachusetts      6.162038e+12
# Oregon             5.884474e+12
# Washington         5.884474e+12
# New Mexico         5.591218e+12
# Maine              5.591218e+12
# Wyoming            5.279656e+12
# North Carolina     4.586494e+12
# total_chairs       4.275933e+12
# Ohio               4.193333e+12
# Connecticut        4.193333e+12
# Nevada             3.756397e+12
# Illinois           3.756397e+12
# Virginia           3.756397e+12
# West Virginia      3.756397e+12
# Iowa               3.258121e+12
# Alaska             3.258121e+12
# Indiana            2.664309e+12
# South Dakota       2.664309e+12
# Missouri           2.664309e+12
# Arizona            2.664309e+12
# New Jersey         2.664309e+12
# Rhode Island       1.886821e+12
# Maryland           1.886821e+12
# Tennessee          1.886821e+12
# fastQuads          1.621016e+12
# surface            1.518770e+12
# double             1.338397e+12
# triple             1.193942e+12
# quad               9.676457e+11
# fastSixes          4.805510e+11
# trams              4.129028e+11
# fastEight          4.059239e+10
# AdultWeekday       1.934959e+01
# vertical_drop      1.440658e+00
# Runs               1.157305e+00
# NightSkiing_ac     7.042745e-01
# daysOpenLastYear   6.503956e-01
# Snow Making_ac     4.920711e-01
# LongestRun_mi      4.078444e-01
# yearsOpen          3.742967e-01
# SkiableTerrain_ac  2.080603e-01
# projectedDaysOpen  1.375533e-01
# TerrainParks       8.058350e-02
# averageSnowfall    6.816861e-02

# %% [markdown]
# ## Identify the Final Model

# %% [markdown]
# **<font color='teal'> Review the model performances in the table below and choose the best model for proving insights to Big Mountain management about what features are driving ski resort lift ticket prices. Type your choice in the final markdown cell — you will discuss this selection more in the next step of the guided casptone. </font>**

# %% [markdown]
# | Model | Explained Variance| Mean Absolute Error|Features Dropped|
# | --- | --- | --- | --- |
# | Model 1. | 0.93 | 5.07 | - |
# | Model 2. | 0.92 | 5.50 | 'state' |
# | Model 3. | 0.93 | 5.46 | 'state','summit_elev','base_elev' |
# | Model 4. | 0.94 | 4.90 | 'summit_elev','base_elev' |

# %% [markdown]
# Model Selection:

# %% [markdown]
# **Model 4**
